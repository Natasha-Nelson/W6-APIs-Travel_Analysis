# %%
#import dependencies
import pandas as pd
import numpy as np
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aklavik
# Processing Record 2 of Set 1 | kahului
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 1 | cabo san lucas
# Processing Record 8 of Set 1 | kokopo
# Processing Record 9 of Set 1 | carahue
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | lakatoro
# Processing Record 12 of Set 1 | ballitoville
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | eyl
# Processing Record 17 of Set 1 | vallenar
# Processing Record 18 of Set 1 | cherlak
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | juifang
# City not found. Skipping...
# Processing Record 22 of Set 1 | salalah
# Processing Record 23 of Set 1 | trairi
# Processing Record 24 of Set 1 | neiafu
# Processing Record 25 of Set 1 | ostrovnoy
# Processing Record 26 of Set 1 | kovdor
# Processing Record 27 of Set 1 | victoria
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | broome
# Processing Record 32 of Set 1 | khovu-aksy
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | west bay
# Processing Record 35 of Set 1 | oriximina
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | klyuchi
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | diffa
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | ahipara
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | bethel
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | phan thiet
# Processing Record 2 of Set 2 | abilene
# Processing Record 3 of Set 2 | meulaboh
# Processing Record 4 of Set 2 | dzhida
# Processing Record 5 of Set 2 | fukue
# Processing Record 6 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 2 | jawhar
# Processing Record 8 of Set 2 | nioro
# Processing Record 9 of Set 2 | nautla
# Processing Record 10 of Set 2 | tarko-sale
# Processing Record 11 of Set 2 | fortuna
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | gimli
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | horta
# Processing Record 16 of Set 2 | butte
# Processing Record 17 of Set 2 | sao raimundo das mangabeiras
# Processing Record 18 of Set 2 | jaciara
# Processing Record 19 of Set 2 | coihaique
# Processing Record 20 of Set 2 | mahebourg
# Processing Record 21 of Set 2 | great yarmouth
# Processing Record 22 of Set 2 | bilibino
# Processing Record 23 of Set 2 | ushuaia
# Processing Record 24 of Set 2 | yabelo
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | kavieng
# Processing Record 27 of Set 2 | bethanien
# Processing Record 28 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 2 | loralai
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | qaqortoq
# Processing Record 32 of Set 2 | athabasca
# Processing Record 33 of Set 2 | opuwo
# Processing Record 34 of Set 2 | morozovsk
# Processing Record 35 of Set 2 | gornopravdinsk
# Processing Record 36 of Set 2 | tuatapere
# Processing Record 37 of Set 2 | tamala
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | washougal
# Processing Record 40 of Set 2 | kungurtug
# Processing Record 41 of Set 2 | mackay
# Processing Record 42 of Set 2 | laguna
# Processing Record 43 of Set 2 | patrasaer
# Processing Record 44 of Set 2 | port-gentil
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | chapais
# Processing Record 48 of Set 2 | escanaba
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | dwarka
# Processing Record 1 of Set 3 | maputo
# Processing Record 2 of Set 3 | vestbygda
# City not found. Skipping...
# Processing Record 3 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 3 | maniitsoq
# Processing Record 5 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | coquimbo
# Processing Record 9 of Set 3 | hofn
# Processing Record 10 of Set 3 | novobiryusinskiy
# Processing Record 11 of Set 3 | neftcala
# Processing Record 12 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 3 | luderitz
# Processing Record 14 of Set 3 | salym
# Processing Record 15 of Set 3 | kapit
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | real
# Processing Record 18 of Set 3 | faanui
# Processing Record 19 of Set 3 | haines junction
# Processing Record 20 of Set 3 | isla vista
# Processing Record 21 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 3 | moose factory
# Processing Record 23 of Set 3 | bathsheba
# Processing Record 24 of Set 3 | adrar
# Processing Record 25 of Set 3 | jieshi
# Processing Record 26 of Set 3 | severo-kurilsk
# Processing Record 27 of Set 3 | vaitape
# Processing Record 28 of Set 3 | katsuura
# Processing Record 29 of Set 3 | hit
# Processing Record 30 of Set 3 | bay roberts
# Processing Record 31 of Set 3 | kavaratti
# Processing Record 32 of Set 3 | arica
# Processing Record 33 of Set 3 | byron bay
# Processing Record 34 of Set 3 | tonota
# Processing Record 35 of Set 3 | saldanha
# Processing Record 36 of Set 3 | hithadhoo
# Processing Record 37 of Set 3 | ketchikan
# Processing Record 38 of Set 3 | cabras
# Processing Record 39 of Set 3 | coruripe
# Processing Record 40 of Set 3 | belousovka
# Processing Record 41 of Set 3 | manta
# Processing Record 42 of Set 3 | cherskiy
# Processing Record 43 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 3 | butaritari
# Processing Record 45 of Set 3 | ylivieska
# Processing Record 46 of Set 3 | hilo
# Processing Record 47 of Set 3 | castro
# Processing Record 48 of Set 3 | lamu
# Processing Record 49 of Set 3 | zheleznogorsk-ilimskiy
# Processing Record 50 of Set 3 | alekseyevsk
# Processing Record 1 of Set 4 | ateptsevo
# Processing Record 2 of Set 4 | tual
# Processing Record 3 of Set 4 | port blair
# Processing Record 4 of Set 4 | severo-yeniseyskiy
# Processing Record 5 of Set 4 | coxim
# Processing Record 6 of Set 4 | hermanus
# Processing Record 7 of Set 4 | dali
# Processing Record 8 of Set 4 | aljezur
# Processing Record 9 of Set 4 | kruisfontein
# Processing Record 10 of Set 4 | sao gabriel
# Processing Record 11 of Set 4 | red bluff
# Processing Record 12 of Set 4 | orangeburg
# Processing Record 13 of Set 4 | gamba
# Processing Record 14 of Set 4 | stornoway
# Processing Record 15 of Set 4 | batagay
# Processing Record 16 of Set 4 | phrai bung
# City not found. Skipping...
# Processing Record 17 of Set 4 | leningradskiy
# Processing Record 18 of Set 4 | bubaque
# Processing Record 19 of Set 4 | hasaki
# Processing Record 20 of Set 4 | la ronge
# Processing Record 21 of Set 4 | paka
# Processing Record 22 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 4 | puqi
# Processing Record 24 of Set 4 | cidreira
# Processing Record 25 of Set 4 | kaitangata
# Processing Record 26 of Set 4 | chokurdakh
# Processing Record 27 of Set 4 | alta floresta
# Processing Record 28 of Set 4 | pilao arcado
# City not found. Skipping...
# Processing Record 29 of Set 4 | airai
# Processing Record 30 of Set 4 | axim
# Processing Record 31 of Set 4 | mataram
# Processing Record 32 of Set 4 | asosa
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | alice springs
# Processing Record 35 of Set 4 | ribeira grande
# Processing Record 36 of Set 4 | barra do garcas
# Processing Record 37 of Set 4 | fairbanks
# Processing Record 38 of Set 4 | orlik
# Processing Record 39 of Set 4 | nantucket
# Processing Record 40 of Set 4 | ucluelet
# Processing Record 41 of Set 4 | grand gaube
# Processing Record 42 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 4 | biak
# Processing Record 44 of Set 4 | tiznit
# Processing Record 45 of Set 4 | saint george
# Processing Record 46 of Set 4 | saint anthony
# Processing Record 47 of Set 4 | gumushane
# City not found. Skipping...
# Processing Record 48 of Set 4 | khyriv
# Processing Record 49 of Set 4 | arraial do cabo
# Processing Record 50 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 5 | pinyug
# Processing Record 2 of Set 5 | tahlequah
# Processing Record 3 of Set 5 | lachi
# Processing Record 4 of Set 5 | talnakh
# Processing Record 5 of Set 5 | cubarral
# Processing Record 6 of Set 5 | kroderen
# City not found. Skipping...
# Processing Record 7 of Set 5 | bolshaya sosnova
# Processing Record 8 of Set 5 | taguisa
# Processing Record 9 of Set 5 | hokitika
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | saint-joseph
# Processing Record 12 of Set 5 | rocha
# Processing Record 13 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 5 | itarema
# Processing Record 15 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 16 of Set 5 | new norfolk
# Processing Record 17 of Set 5 | havre-saint-pierre
# Processing Record 18 of Set 5 | kenai
# Processing Record 19 of Set 5 | freeport
# Processing Record 20 of Set 5 | quibor
# Processing Record 21 of Set 5 | vega de alatorre
# Processing Record 22 of Set 5 | nanortalik
# Processing Record 23 of Set 5 | velizh
# Processing Record 24 of Set 5 | carutapera
# Processing Record 25 of Set 5 | chulym
# Processing Record 26 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 5 | espinosa
# Processing Record 28 of Set 5 | sarakhs
# Processing Record 29 of Set 5 | hobyo
# Processing Record 30 of Set 5 | kholm
# Processing Record 31 of Set 5 | sobolevo
# Processing Record 32 of Set 5 | fuyang
# Processing Record 33 of Set 5 | san jeronimo
# Processing Record 34 of Set 5 | karasjok
# Processing Record 35 of Set 5 | tuktoyaktuk
# Processing Record 36 of Set 5 | usinsk
# Processing Record 37 of Set 5 | cayenne
# Processing Record 38 of Set 5 | san andres
# Processing Record 39 of Set 5 | gigmoto
# Processing Record 40 of Set 5 | arkhangelos
# City not found. Skipping...
# Processing Record 41 of Set 5 | longyearbyen
# Processing Record 42 of Set 5 | deputatskiy
# Processing Record 43 of Set 5 | dakar
# Processing Record 44 of Set 5 | barrow
# Processing Record 45 of Set 5 | challapata
# Processing Record 46 of Set 5 | sept-iles
# Processing Record 47 of Set 5 | carnarvon
# Processing Record 48 of Set 5 | svetlogorsk
# Processing Record 49 of Set 5 | winslow
# Processing Record 50 of Set 5 | bereda
# Processing Record 1 of Set 6 | luanda
# Processing Record 2 of Set 6 | mount isa
# Processing Record 3 of Set 6 | san quintin
# Processing Record 4 of Set 6 | chadan
# Processing Record 5 of Set 6 | yar-sale
# Processing Record 6 of Set 6 | bukachacha
# Processing Record 7 of Set 6 | lander
# Processing Record 8 of Set 6 | forio
# Processing Record 9 of Set 6 | kattivakkam
# Processing Record 10 of Set 6 | saint-jean-de-la-ruelle
# Processing Record 11 of Set 6 | alugan
# Processing Record 12 of Set 6 | baykit
# Processing Record 13 of Set 6 | leh
# Processing Record 14 of Set 6 | svetlaya
# Processing Record 15 of Set 6 | pacific grove
# Processing Record 16 of Set 6 | ancud
# Processing Record 17 of Set 6 | kodinsk
# Processing Record 18 of Set 6 | dongsheng
# Processing Record 19 of Set 6 | vilhena
# Processing Record 20 of Set 6 | ilulissat
# Processing Record 21 of Set 6 | constitucion
# Processing Record 22 of Set 6 | kandrian
# Processing Record 23 of Set 6 | puerto escondido
# Processing Record 24 of Set 6 | turtas
# Processing Record 25 of Set 6 | khani
# Processing Record 26 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 6 | sakakah
# Processing Record 28 of Set 6 | pangkalanbuun
# Processing Record 29 of Set 6 | upernavik
# Processing Record 30 of Set 6 | riberalta
# Processing Record 31 of Set 6 | north bend
# Processing Record 32 of Set 6 | grindavik
# Processing Record 33 of Set 6 | lata
# Processing Record 34 of Set 6 | husavik
# Processing Record 35 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 6 | la romana
# Processing Record 37 of Set 6 | santa cruz
# Processing Record 38 of Set 6 | chara
# Processing Record 39 of Set 6 | disna
# Processing Record 40 of Set 6 | lompoc
# Processing Record 41 of Set 6 | samarai
# Processing Record 42 of Set 6 | guerrero negro
# Processing Record 43 of Set 6 | puerto madryn
# Processing Record 44 of Set 6 | sitka
# Processing Record 45 of Set 6 | tocopilla
# Processing Record 46 of Set 6 | ust-maya
# Processing Record 47 of Set 6 | asfi
# Processing Record 48 of Set 6 | fuxin
# Processing Record 49 of Set 6 | pisco
# Processing Record 50 of Set 6 | thompson
# Processing Record 1 of Set 7 | ahuimanu
# Processing Record 2 of Set 7 | arona
# Processing Record 3 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 7 | bandarbeyla
# Processing Record 5 of Set 7 | katangli
# Processing Record 6 of Set 7 | saskylakh
# Processing Record 7 of Set 7 | vestmanna
# Processing Record 8 of Set 7 | porto novo
# Processing Record 9 of Set 7 | egvekinot
# Processing Record 10 of Set 7 | canto do buriti
# Processing Record 11 of Set 7 | okhotsk
# Processing Record 12 of Set 7 | hervey bay
# Processing Record 13 of Set 7 | zaysan
# Processing Record 14 of Set 7 | yaan
# Processing Record 15 of Set 7 | tokur
# Processing Record 16 of Set 7 | cascavel
# Processing Record 17 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 7 | neuquen
# Processing Record 19 of Set 7 | ware
# Processing Record 20 of Set 7 | bastia
# Processing Record 21 of Set 7 | san ignacio
# Processing Record 22 of Set 7 | clyde river
# Processing Record 23 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 7 | porto santo
# Processing Record 25 of Set 7 | utevka
# Processing Record 26 of Set 7 | muros
# Processing Record 27 of Set 7 | kailua
# Processing Record 28 of Set 7 | eyemouth
# Processing Record 29 of Set 7 | naberera
# Processing Record 30 of Set 7 | namuac
# Processing Record 31 of Set 7 | komsomolskiy
# Processing Record 32 of Set 7 | lishu
# Processing Record 33 of Set 7 | kamenka
# Processing Record 34 of Set 7 | mezhova
# Processing Record 35 of Set 7 | chicama
# Processing Record 36 of Set 7 | platteville
# Processing Record 37 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 7 | haifa
# Processing Record 39 of Set 7 | jiuquan
# Processing Record 40 of Set 7 | ornskoldsvik
# Processing Record 41 of Set 7 | beyneu
# Processing Record 42 of Set 7 | edd
# Processing Record 43 of Set 7 | georgetown
# Processing Record 44 of Set 7 | padang
# Processing Record 45 of Set 7 | corner brook
# Processing Record 46 of Set 7 | fare
# Processing Record 47 of Set 7 | raymond
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | laem sing
# Processing Record 50 of Set 7 | abaete
# Processing Record 1 of Set 8 | luganville
# Processing Record 2 of Set 8 | penha
# Processing Record 3 of Set 8 | kemijarvi
# Processing Record 4 of Set 8 | khasan
# Processing Record 5 of Set 8 | sinjah
# City not found. Skipping...
# Processing Record 6 of Set 8 | shieli
# Processing Record 7 of Set 8 | narsaq
# Processing Record 8 of Set 8 | westport
# Processing Record 9 of Set 8 | ofaqim
# Processing Record 10 of Set 8 | srednekolymsk
# Processing Record 11 of Set 8 | lodja
# Processing Record 12 of Set 8 | port lincoln
# Processing Record 13 of Set 8 | russell
# Processing Record 14 of Set 8 | sabang
# Processing Record 15 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 16 of Set 8 | karatau
# Processing Record 17 of Set 8 | podgornoye
# Processing Record 18 of Set 8 | moree
# Processing Record 19 of Set 8 | nakhon phanom
# Processing Record 20 of Set 8 | grenaa
# Processing Record 21 of Set 8 | ratnagiri
# Processing Record 22 of Set 8 | petrolandia
# City not found. Skipping...
# Processing Record 23 of Set 8 | vostok
# Processing Record 24 of Set 8 | shahpur
# Processing Record 25 of Set 8 | kuna
# Processing Record 26 of Set 8 | rio grande
# Processing Record 27 of Set 8 | flin flon
# Processing Record 28 of Set 8 | mizan teferi
# Processing Record 29 of Set 8 | megion
# Processing Record 30 of Set 8 | sandane
# Processing Record 31 of Set 8 | beatrice
# Processing Record 32 of Set 8 | ziro
# Processing Record 33 of Set 8 | goderich
# Processing Record 34 of Set 8 | monteria
# Processing Record 35 of Set 8 | berbera
# Processing Record 36 of Set 8 | raga
# Processing Record 37 of Set 8 | gazli
# Processing Record 38 of Set 8 | abu dhabi
# Processing Record 39 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 8 | bilma
# Processing Record 41 of Set 8 | lebu
# Processing Record 42 of Set 8 | lagoa
# Processing Record 43 of Set 8 | selma
# Processing Record 44 of Set 8 | chuy
# Processing Record 45 of Set 8 | xinzhou
# Processing Record 46 of Set 8 | iguape
# Processing Record 47 of Set 8 | hay river
# Processing Record 48 of Set 8 | geraldton
# Processing Record 49 of Set 8 | balkanabat
# Processing Record 50 of Set 8 | ko samui
# Processing Record 1 of Set 9 | morristown
# Processing Record 2 of Set 9 | villa bruzual
# Processing Record 3 of Set 9 | balyaga
# Processing Record 4 of Set 9 | abay
# Processing Record 5 of Set 9 | talara
# Processing Record 6 of Set 9 | sibu
# Processing Record 7 of Set 9 | kununurra
# Processing Record 8 of Set 9 | esperance
# Processing Record 9 of Set 9 | the valley
# Processing Record 10 of Set 9 | naryan-mar
# Processing Record 11 of Set 9 | omboue
# Processing Record 12 of Set 9 | ca mau
# Processing Record 13 of Set 9 | winnemucca
# Processing Record 14 of Set 9 | wawa
# Processing Record 15 of Set 9 | chernyshevskiy
# Processing Record 16 of Set 9 | coahuayana
# Processing Record 17 of Set 9 | talaya
# Processing Record 18 of Set 9 | vanavara
# Processing Record 19 of Set 9 | batemans bay
# Processing Record 20 of Set 9 | bukama
# Processing Record 21 of Set 9 | verkhnevilyuysk
# Processing Record 22 of Set 9 | inhambane
# Processing Record 23 of Set 9 | cairns
# Processing Record 24 of Set 9 | hamilton
# Processing Record 25 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 9 | brownwood
# Processing Record 27 of Set 9 | matay
# Processing Record 28 of Set 9 | baranain
# Processing Record 29 of Set 9 | san patricio
# Processing Record 30 of Set 9 | doha
# Processing Record 31 of Set 9 | waingapu
# Processing Record 32 of Set 9 | mehamn
# Processing Record 33 of Set 9 | lavrentiya
# Processing Record 34 of Set 9 | saint-pierre
# Processing Record 35 of Set 9 | kharp
# Processing Record 36 of Set 9 | marzuq
# Processing Record 37 of Set 9 | hami
# Processing Record 38 of Set 9 | along
# Processing Record 39 of Set 9 | urucara
# Processing Record 40 of Set 9 | awjilah
# Processing Record 41 of Set 9 | shenzhen
# Processing Record 42 of Set 9 | sao joao da barra
# Processing Record 43 of Set 9 | sibolga
# Processing Record 44 of Set 9 | benalla
# Processing Record 45 of Set 9 | matara
# Processing Record 46 of Set 9 | vila velha
# Processing Record 47 of Set 9 | iqaluit
# Processing Record 48 of Set 9 | tarakan
# Processing Record 49 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 9 | magan
# Processing Record 1 of Set 10 | rawson
# Processing Record 2 of Set 10 | taunggyi
# Processing Record 3 of Set 10 | jumla
# Processing Record 4 of Set 10 | berlevag
# Processing Record 5 of Set 10 | pevek
# Processing Record 6 of Set 10 | prieska
# Processing Record 7 of Set 10 | uporovo
# Processing Record 8 of Set 10 | tiksi
# Processing Record 9 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 10 | bengkulu
# Processing Record 11 of Set 10 | lalmohan
# Processing Record 12 of Set 10 | rivne
# Processing Record 13 of Set 10 | huarmey
# Processing Record 14 of Set 10 | kuybyshevo
# Processing Record 15 of Set 10 | kichera
# Processing Record 16 of Set 10 | burica
# City not found. Skipping...
# Processing Record 17 of Set 10 | skjervoy
# Processing Record 18 of Set 10 | finschhafen
# Processing Record 19 of Set 10 | codrington
# Processing Record 20 of Set 10 | belogorsk
# Processing Record 21 of Set 10 | sioux lookout
# Processing Record 22 of Set 10 | akdagmadeni
# Processing Record 23 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 10 | kendal
# Processing Record 25 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 26 of Set 10 | sheboygan
# Processing Record 27 of Set 10 | vilyuysk
# Processing Record 28 of Set 10 | zhigansk
# Processing Record 29 of Set 10 | sayyan
# Processing Record 30 of Set 10 | hornepayne
# Processing Record 31 of Set 10 | flinders
# Processing Record 32 of Set 10 | gerash
# Processing Record 33 of Set 10 | pemangkat
# Processing Record 34 of Set 10 | saint-georges
# Processing Record 35 of Set 10 | coffs harbour
# Processing Record 36 of Set 10 | auki
# Processing Record 37 of Set 10 | alofi
# Processing Record 38 of Set 10 | klaksvik
# Processing Record 39 of Set 10 | vestmannaeyjar
# Processing Record 40 of Set 10 | linhares
# Processing Record 41 of Set 10 | kalmar
# Processing Record 42 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 10 | ust-nera
# Processing Record 44 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 10 | la asuncion
# Processing Record 46 of Set 10 | camacha
# Processing Record 47 of Set 10 | champasak
# Processing Record 48 of Set 10 | araouane
# Processing Record 49 of Set 10 | middelburg
# Processing Record 50 of Set 10 | nome
# Processing Record 1 of Set 11 | baculin
# Processing Record 2 of Set 11 | dargaville
# Processing Record 3 of Set 11 | gunupur
# Processing Record 4 of Set 11 | arcachon
# Processing Record 5 of Set 11 | apollonia
# Processing Record 6 of Set 11 | atambua
# Processing Record 7 of Set 11 | tashtyp
# Processing Record 8 of Set 11 | perth
# Processing Record 9 of Set 11 | port hardy
# Processing Record 10 of Set 11 | orzu
# Processing Record 11 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 11 | boa vista
# Processing Record 14 of Set 11 | coetupo
# City not found. Skipping...
# Processing Record 15 of Set 11 | svetlyy
# Processing Record 16 of Set 11 | bengkalis
# City not found. Skipping...
# Processing Record 17 of Set 11 | namibe
# Processing Record 18 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 11 | illapel
# Processing Record 20 of Set 11 | campoalegre
# Processing Record 21 of Set 11 | noumea
# Processing Record 22 of Set 11 | tarauaca
# Processing Record 23 of Set 11 | juliaca
# Processing Record 24 of Set 11 | puerto ayacucho
# Processing Record 25 of Set 11 | sola
# Processing Record 26 of Set 11 | marsaxlokk
# Processing Record 27 of Set 11 | lorengau
# Processing Record 28 of Set 11 | bulaevo
# Processing Record 29 of Set 11 | bonavista
# Processing Record 30 of Set 11 | juegang
# Processing Record 31 of Set 11 | nenjiang
# Processing Record 32 of Set 11 | pashiya
# Processing Record 33 of Set 11 | uyaan
# Processing Record 34 of Set 11 | paragominas
# Processing Record 35 of Set 11 | mersing
# Processing Record 36 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 11 | batagay-alyta
# Processing Record 38 of Set 11 | kaeo
# Processing Record 39 of Set 11 | kirakira
# Processing Record 40 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 11 | te anau
# Processing Record 42 of Set 11 | balarampur
# Processing Record 43 of Set 11 | vao
# Processing Record 44 of Set 11 | atar
# Processing Record 45 of Set 11 | teya
# Processing Record 46 of Set 11 | henties bay
# Processing Record 47 of Set 11 | thai binh
# Processing Record 48 of Set 11 | niquero
# Processing Record 49 of Set 11 | rio muerto
# Processing Record 50 of Set 11 | kimberley
# Processing Record 1 of Set 12 | monrovia
# Processing Record 2 of Set 12 | nhulunbuy
# Processing Record 3 of Set 12 | tilichiki
# Processing Record 4 of Set 12 | urdoma
# Processing Record 5 of Set 12 | kangaatsiaq
# Processing Record 6 of Set 12 | hammerfest
# Processing Record 7 of Set 12 | bud
# Processing Record 8 of Set 12 | cascais
# Processing Record 9 of Set 12 | plettenberg bay
# Processing Record 10 of Set 12 | nagaur
# Processing Record 11 of Set 12 | suntar
# Processing Record 12 of Set 12 | hambantota
# Processing Record 13 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 12 | necochea
# Processing Record 15 of Set 12 | alwar
# Processing Record 16 of Set 12 | pelym
# Processing Record 17 of Set 12 | tura
# Processing Record 18 of Set 12 | nanakuli
# Processing Record 19 of Set 12 | mnogovershinnyy
# Processing Record 20 of Set 12 | labuhan
# Processing Record 21 of Set 12 | vila franca do campo
# Processing Record 22 of Set 12 | ossora
# Processing Record 23 of Set 12 | port dover
# Processing Record 24 of Set 12 | warri
# Processing Record 25 of Set 12 | manjeshwar
# Processing Record 26 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 12 | olinda
# Processing Record 28 of Set 12 | loiza
# Processing Record 29 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 12 | istok
# Processing Record 31 of Set 12 | qandala
# Processing Record 32 of Set 12 | pangody
# Processing Record 33 of Set 12 | buncrana
# Processing Record 34 of Set 12 | tuy hoa
# Processing Record 35 of Set 12 | boleslawiec
# Processing Record 36 of Set 12 | tacuati
# Processing Record 37 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 38 of Set 12 | wanaka
# Processing Record 39 of Set 12 | richards bay
# Processing Record 40 of Set 12 | great bend
# Processing Record 41 of Set 12 | malm
# Processing Record 42 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 43 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 12 | waipawa
# Processing Record 45 of Set 12 | teguldet
# Processing Record 46 of Set 12 | coihueco
# Processing Record 47 of Set 12 | corinto
# Processing Record 48 of Set 12 | aksu
# Processing Record 49 of Set 12 | aitape
# Processing Record 50 of Set 12 | vredendal
# Processing Record 1 of Set 13 | batticaloa
# Processing Record 2 of Set 13 | maceio
# Processing Record 3 of Set 13 | shimoda
# Processing Record 4 of Set 13 | college
# Processing Record 5 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 6 of Set 13 | bahia blanca
# Processing Record 7 of Set 13 | yangambi
# Processing Record 8 of Set 13 | tingi
# Processing Record 9 of Set 13 | umm kaddadah
# Processing Record 10 of Set 13 | ayan
# Processing Record 11 of Set 13 | malakal
# Processing Record 12 of Set 13 | san juan de uraba
# Processing Record 13 of Set 13 | sao jose da coroa grande
# Processing Record 14 of Set 13 | port hedland
# Processing Record 15 of Set 13 | najran
# Processing Record 16 of Set 13 | lasa
# Processing Record 17 of Set 13 | kibala
# Processing Record 18 of Set 13 | yumen
# Processing Record 19 of Set 13 | staryy nadym
# Processing Record 20 of Set 13 | carroll
# Processing Record 21 of Set 13 | vidim
# Processing Record 22 of Set 13 | olafsvik
# Processing Record 23 of Set 13 | zabid
# Processing Record 24 of Set 13 | kashi
# Processing Record 25 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 26 of Set 13 | mitsamiouli
# Processing Record 27 of Set 13 | hoquiam
# Processing Record 28 of Set 13 | nha trang
# Processing Record 29 of Set 13 | tsabong
# Processing Record 30 of Set 13 | kyren
# Processing Record 31 of Set 13 | gaya
# Processing Record 32 of Set 13 | paamiut
# Processing Record 33 of Set 13 | nsanje
# Processing Record 34 of Set 13 | mangrol
# Processing Record 35 of Set 13 | asau
# Processing Record 36 of Set 13 | luangwa
# Processing Record 37 of Set 13 | yambio
# Processing Record 38 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 39 of Set 13 | mozzozzin
# Processing Record 40 of Set 13 | umtata
# Processing Record 41 of Set 13 | torbay
# Processing Record 42 of Set 13 | andenes
# Processing Record 43 of Set 13 | manzhouli
# Processing Record 44 of Set 13 | himora
# City not found. Skipping...
# Processing Record 45 of Set 13 | mayor pablo lagerenza
# Processing Record 46 of Set 13 | chon daen
# Processing Record 47 of Set 13 | parambu
# Processing Record 48 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 49 of Set 13 | yarim
# Processing Record 50 of Set 13 | sikonge
# Processing Record 1 of Set 14 | belle glade
# Processing Record 2 of Set 14 | san luis
# Processing Record 3 of Set 14 | buritizeiro
# Processing Record 4 of Set 14 | mitu
# Processing Record 5 of Set 14 | karratha
# Processing Record 6 of Set 14 | havelock
# Processing Record 7 of Set 14 | buchanan
# Processing Record 8 of Set 14 | superior
# Processing Record 9 of Set 14 | banda aceh
# Processing Record 10 of Set 14 | palmer
# Processing Record 11 of Set 14 | vardo
# Processing Record 12 of Set 14 | mahibadhoo
# Processing Record 13 of Set 14 | dolores
# Processing Record 14 of Set 14 | xining
# Processing Record 15 of Set 14 | sao sebastiao
# Processing Record 16 of Set 14 | faro
# Processing Record 17 of Set 14 | beloha
# Processing Record 18 of Set 14 | isiro
# Processing Record 19 of Set 14 | caiaponia
# Processing Record 20 of Set 14 | taoudenni
# Processing Record 21 of Set 14 | cuenca
# Processing Record 22 of Set 14 | roald
# Processing Record 23 of Set 14 | hudiksvall
# Processing Record 24 of Set 14 | midrand
# Processing Record 25 of Set 14 | robat karim
# Processing Record 26 of Set 14 | zhongshan
# Processing Record 27 of Set 14 | guerrero
# Processing Record 28 of Set 14 | fort nelson
# Processing Record 29 of Set 14 | rio gallegos
# Processing Record 30 of Set 14 | kapuskasing
# Processing Record 31 of Set 14 | tifton
# Processing Record 32 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 33 of Set 14 | belyy yar
# Processing Record 34 of Set 14 | arlit
# Processing Record 35 of Set 14 | kotelnich
# Processing Record 36 of Set 14 | harrisburg
# Processing Record 37 of Set 14 | kloulklubed
# Processing Record 38 of Set 14 | balabac
# Processing Record 39 of Set 14 | shaoyang
# Processing Record 40 of Set 14 | topchanchi
# Processing Record 41 of Set 14 | japoata
# Processing Record 42 of Set 14 | zhanakorgan
# Processing Record 43 of Set 14 | smidovich
# Processing Record 44 of Set 14 | filingue
# Processing Record 45 of Set 14 | port-cartier
# Processing Record 46 of Set 14 | tab
# Processing Record 47 of Set 14 | rundu
# Processing Record 48 of Set 14 | gat
# Processing Record 49 of Set 14 | ballina
# Processing Record 50 of Set 14 | cozumel
# Processing Record 1 of Set 15 | taganak
# Processing Record 2 of Set 15 | kupang
# Processing Record 3 of Set 15 | tambovka
# Processing Record 4 of Set 15 | portland
# Processing Record 5 of Set 15 | lebork
# Processing Record 6 of Set 15 | margate
# Processing Record 7 of Set 15 | thinadhoo
# Processing Record 8 of Set 15 | paramonga
# Processing Record 9 of Set 15 | faya
# Processing Record 10 of Set 15 | hurghada
# Processing Record 11 of Set 15 | sur
# Processing Record 12 of Set 15 | yulara
# Processing Record 13 of Set 15 | knysna
# Processing Record 14 of Set 15 | mecca
# Processing Record 15 of Set 15 | ashford
# Processing Record 16 of Set 15 | meadow lake
# Processing Record 17 of Set 15 | sao filipe
# Processing Record 18 of Set 15 | kaoma
# Processing Record 19 of Set 15 | belmonte
# Processing Record 20 of Set 15 | ajdabiya
# Processing Record 21 of Set 15 | oum hadjer
# Processing Record 22 of Set 15 | male
# Processing Record 23 of Set 15 | lira
# Processing Record 24 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 25 of Set 15 | wamba
# Processing Record 26 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 27 of Set 15 | stephenville
# Processing Record 28 of Set 15 | sinnamary
# Processing Record 29 of Set 15 | nambucca heads
# Processing Record 30 of Set 15 | viedma
# Processing Record 31 of Set 15 | georgiyevka
# Processing Record 32 of Set 15 | a coruna
# Processing Record 33 of Set 15 | karlstad
# Processing Record 34 of Set 15 | kedrovyy
# Processing Record 35 of Set 15 | shirokiy
# Processing Record 36 of Set 15 | barranca
# Processing Record 37 of Set 15 | soltsy
# Processing Record 38 of Set 15 | meridian
# Processing Record 39 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 15 | ludvika
# Processing Record 41 of Set 15 | avera
# Processing Record 42 of Set 15 | khuzdar
# Processing Record 43 of Set 15 | panzhihua
# Processing Record 44 of Set 15 | pinas
# Processing Record 45 of Set 15 | bitung
# Processing Record 46 of Set 15 | tororo
# Processing Record 47 of Set 15 | pangnirtung
# Processing Record 48 of Set 15 | mao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Aklavik      CA  68.2191 -135.0107     35.60        87          75
# 1         Kahului      US  20.8947 -156.4700     82.98        74          20
# 2          Dikson      RU  73.5069   80.5464     29.84        96         100
# 3         Mataura      NZ -46.1927  168.8643     39.15        96           7
# 4  Port Elizabeth      ZA -33.9180   25.5701     52.09        76          40
# 5  Cabo San Lucas      MX  22.8909 -109.9124     91.81        50           1
# 6          Kokopo      PG  -4.3520  152.2633     76.03        88         100
# 7         Carahue      CL -38.7000  -73.1667     48.40        68         100
# 8          Kodiak      US  57.7900 -152.4072     47.71        76           1
# 9        Lakatoro      VU -16.0999  167.4164     74.53        76         100
#
#    Wind Speed Current Description
# 0       17.27       broken clouds
# 1       12.66          few clouds
# 2       18.88          light snow
# 3        1.90           clear sky
# 4        3.44    scattered clouds
# 5        4.61           clear sky
# 6        4.36     overcast clouds
# 7        1.36     overcast clouds
# 8        6.91           clear sky
# 9        7.34     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
